# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyaB8/TinyML-Course-Work/blob/main/2-2-5-FirstNeuralNetworkRevisited.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# #### First lets re-train our original single layer network and see what the prediction is for X = 10.0 and what the learned weights are.

# %%
my_layer = keras.layers.Dense(units=1, input_shape=[1])
model = tf.keras.Sequential([my_layer])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 496ms/step - loss: 1.7988
# Epoch 2/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5563
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3626
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2073
# Epoch 5/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0824
# Epoch 6/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9814
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8993
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.8321
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7766
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.7305
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6918
# Epoch 12/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6589
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.985926]]

# %%
print(my_layer.get_weights())
# Out:
# [array([[1.9979602]], dtype=float32), array([-0.9936763], dtype=float32)]

# %% [markdown]
# #### Next lets train a 2-layer network and see what its prediction and weights are.

# %%
my_layer_1 = keras.layers.Dense(units=2, input_shape=[1])
my_layer_2 = keras.layers.Dense(units=1)
model = tf.keras.Sequential([my_layer_1, my_layer_2])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 254ms/step - loss: 5.2181
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4557
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3146
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.8796
# Epoch 5/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.7077
# Epoch 6/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6226
# Epoch 7/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5653
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5180
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4759
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4373
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4017
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3689
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[19.]]

# %%
print(my_layer_1.get_weights())
print(my_layer_2.get_weights())
# Out:
# [array([[ 1.3373185 , -0.02031761]], dtype=float32), array([-0.34295455,  0.2434259 ], dtype=float32)]
# [array([[ 1.4796942],
#        [-1.0423089]], dtype=float32), array([-0.23880649], dtype=float32)]

# %% [markdown]
# #### Finally we can manually compute the output for our 2-layer network to better understand how it works.

# %%
value_to_predict = 10.0

layer1_w1 = (my_layer_1.get_weights()[0][0][0])
layer1_w2 = (my_layer_1.get_weights()[0][0][1])
layer1_b1 = (my_layer_1.get_weights()[1][0])
layer1_b2 = (my_layer_1.get_weights()[1][1])


layer2_w1 = (my_layer_2.get_weights()[0][0])
layer2_w2 = (my_layer_2.get_weights()[0][1])
layer2_b = (my_layer_2.get_weights()[1][0])

neuron1_output = (layer1_w1 * value_to_predict) + layer1_b1
neuron2_output = (layer1_w2 * value_to_predict) + layer1_b2

neuron3_output = (layer2_w1 * neuron1_output) + (layer2_w2 * neuron2_output) + layer2_b

print(neuron3_output)
# Out:
# [19.]
